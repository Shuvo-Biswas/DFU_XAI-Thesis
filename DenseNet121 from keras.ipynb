# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives, Precision, Recall, AUC
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
labels = ['Abnormal(Ulcer)','Normal(Healthy skin)']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/DFU_dataset','train',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        try:
            img = cv2.resize(img,(image_size, image_size))
        except:
            break
        X_train.append(img)
        y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/DFU_dataset','test',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 1740/1740 [00:36<00:00, 47.77it/s]
# 100%|██████████| 1170/1170 [00:21<00:00, 54.31it/s]
# 100%|██████████| 175/175 [00:03<00:00, 50.29it/s]
# 100%|██████████| 115/115 [00:02<00:00, 53.68it/s]

# %%
X_train.shape
# Out:
# (3200, 224, 224, 3)

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=1010)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=1010)

# %%
X_test.shape
# Out:
# (320, 224, 224, 3)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import keras
import keras.utils
from keras import utils as np_utils
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils.vis_utils import plot_model

from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential

# %%
IMAGE_SIZE = [224, 224]

# %%
denseNet121 = DenseNet121(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
for layer in denseNet121.layers:
    layer.trainable = False
x = GlobalAveragePooling2D()(denseNet121.output)
x = Dense(1024,activation='relu')(x)
x = Dropout(rate=0.5)(x)
x = Dense(1024,activation='relu')(x)
x = Dropout(rate=0.3)(x)
x = Dense(512,activation='relu')(x)
prediction = Dense(2, activation='softmax')(x)

# create a model object
model = Model(inputs=denseNet121.input, outputs=prediction)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %%
model.summary()

# plot model architecture
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, to_file='DenseNet121.png')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= 'accuracy')

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("DenseNet121.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.4, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/50
# 81/81 [==============================] - ETA: 0s - loss: 1.2212 - accuracy: 0.7280
# Epoch 1: val_accuracy improved from -inf to 0.85069, saving model to DenseNet121.h5
# 81/81 [==============================] - 38s 208ms/step - loss: 1.2212 - accuracy: 0.7280 - val_loss: 0.3924 - val_accuracy: 0.8507 - lr: 0.0010
# Epoch 2/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3892 - accuracy: 0.8407
# Epoch 2: val_accuracy improved from 0.85069 to 0.87847, saving model to DenseNet121.h5
# 81/81 [==============================] - 10s 124ms/step - loss: 0.3892 - accuracy: 0.8407 - val_loss: 0.3188 - val_accuracy: 0.8785 - lr: 0.0010
# Epoch 3/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3541 - accuracy: 0.8480
# Epoch 3: val_accuracy did not improve from 0.87847
# 81/81 [==============================] - 9s 111ms/step - loss: 0.3541 - accuracy: 0.8480 - val_loss: 0.3296 - val_accuracy: 0.8542 - lr: 0.0010
# Epoch 4/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3211 - accuracy: 0.8708
# Epoch 4: val_accuracy improved from 0.87847 to 0.89236, saving model to DenseNet121.h5
# 81/81 [==============================] - 10s 129ms/step - loss: 0.3211 - accuracy: 0.8708 - val_loss: 0.2681 - val_accuracy: 0.8924 - lr: 0.0010
# Epoch 5/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3072 - accuracy: 0.8808
# Epoch 5: val_accuracy did not improve from 0.89236
# 81/81 [==============================] - 9s 113ms/step - loss: 0.3072 - accuracy: 0.8808 - val_loss: 0.2635 - val_accuracy: 0.8924 - lr: 0.0010
# Epoch 6/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2887 - accuracy: 0.8870
# Epoch 6: val_accuracy did not improve from 0.89236
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 81/81 [==============================] - 9s 108ms/step - loss: 0.2887 - accuracy: 0.8870 - val_loss: 0.2502 - val_accuracy: 0.8924 - lr: 0.0010
# Epoch 7/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2481 - accuracy: 0.8985
# Epoch 7: val_accuracy improved from 0.89236 to 0.90278, saving model to DenseNet121.h5
# 81/81 [==============================] - 10s 118ms/step - loss: 0.2481 - accuracy: 0.8985 - val_loss: 0.2345 - val_accuracy: 0.9028 - lr: 4.0000e-04
# Epoch 8/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2151 - accuracy: 0.9120
# Epoch 8: val_accuracy improved from 0.90278 to 0.90625, saving model to DenseNet121.h5
# 81/81 [==============================] - 9s 112ms/step - loss: 0.2151 - accuracy: 0.9120 - val_loss: 0.2313 - val_accuracy: 0.9062 - lr: 4.0000e-04
# Epoch 9/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2109 - accuracy: 0.9136
# Epoch 9: val_accuracy did not improve from 0.90625
# 81/81 [==============================] - 9s 108ms/step - loss: 0.2109 - accuracy: 0.9136 - val_loss: 0.2286 - val_accuracy: 0.9062 - lr: 4.0000e-04
# Epoch 10/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2174 - accuracy: 0.9117
# Epoch 10: val_accuracy did not improve from 0.90625
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 81/81 [==============================] - 9s 108ms/step - loss: 0.2174 - accuracy: 0.9117 - val_loss: 0.2314 - val_accuracy: 0.9062 - lr: 4.0000e-04
# Epoch 11/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1866 - accuracy: 0.9290
# Epoch 11: val_accuracy did not improve from 0.90625
# 81/81 [==============================] - 8s 104ms/step - loss: 0.1866 - accuracy: 0.9290 - val_loss: 0.2089 - val_accuracy: 0.9062 - lr: 1.6000e-04
# Epoch 12/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1796 - accuracy: 0.9313
# Epoch 12: val_accuracy improved from 0.90625 to 0.91667, saving model to DenseNet121.h5
# 81/81 [==============================] - 10s 118ms/step - loss: 0.1796 - accuracy: 0.9313 - val_loss: 0.2117 - val_accuracy: 0.9167 - lr: 1.6000e-04
# Epoch 13/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9313
# Epoch 13: val_accuracy did not improve from 0.91667
# 81/81 [==============================] - 9s 110ms/step - loss: 0.1720 - accuracy: 0.9313 - val_loss: 0.2076 - val_accuracy: 0.9062 - lr: 1.6000e-04
# Epoch 14/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9390
# Epoch 14: val_accuracy did not improve from 0.91667
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 81/81 [==============================] - 8s 104ms/step - loss: 0.1596 - accuracy: 0.9390 - val_loss: 0.2102 - val_accuracy: 0.9132 - lr: 1.6000e-04
# Epoch 15/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1469 - accuracy: 0.9394
# Epoch 15: val_accuracy did not improve from 0.91667
# 81/81 [==============================] - 9s 109ms/step - loss: 0.1469 - accuracy: 0.9394 - val_loss: 0.2124 - val_accuracy: 0.9167 - lr: 6.4000e-05
# Epoch 16/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9367
# Epoch 16: val_accuracy did not improve from 0.91667
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 81/81 [==============================] - 9s 111ms/step - loss: 0.1483 - accuracy: 0.9367 - val_loss: 0.2075 - val_accuracy: 0.9167 - lr: 6.4000e-05
# Epoch 17/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9433
# Epoch 17: val_accuracy did not improve from 0.91667
# 81/81 [==============================] - 9s 111ms/step - loss: 0.1374 - accuracy: 0.9433 - val_loss: 0.2098 - val_accuracy: 0.9167 - lr: 2.5600e-05
# Epoch 18/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9495
# Epoch 18: val_accuracy did not improve from 0.91667
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 81/81 [==============================] - 9s 108ms/step - loss: 0.1424 - accuracy: 0.9495 - val_loss: 0.2107 - val_accuracy: 0.9167 - lr: 2.5600e-05
# Epoch 19/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9414
# Epoch 19: val_accuracy improved from 0.91667 to 0.92014, saving model to DenseNet121.h5
# 81/81 [==============================] - 10s 120ms/step - loss: 0.1406 - accuracy: 0.9414 - val_loss: 0.2096 - val_accuracy: 0.9201 - lr: 1.0240e-05
# Epoch 20/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9471
# Epoch 20: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 9s 110ms/step - loss: 0.1344 - accuracy: 0.9471 - val_loss: 0.2107 - val_accuracy: 0.9167 - lr: 1.0240e-05
# Epoch 21/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1381 - accuracy: 0.9460
# Epoch 21: val_accuracy did not improve from 0.92014
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# 81/81 [==============================] - 9s 109ms/step - loss: 0.1381 - accuracy: 0.9460 - val_loss: 0.2110 - val_accuracy: 0.9201 - lr: 1.0240e-05
# Epoch 22/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1417 - accuracy: 0.9448
# Epoch 22: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 9s 111ms/step - loss: 0.1417 - accuracy: 0.9448 - val_loss: 0.2093 - val_accuracy: 0.9201 - lr: 4.0960e-06
# Epoch 23/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1436 - accuracy: 0.9448
# Epoch 23: val_accuracy did not improve from 0.92014
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.6384001355618238e-06.
# 81/81 [==============================] - 9s 111ms/step - loss: 0.1436 - accuracy: 0.9448 - val_loss: 0.2094 - val_accuracy: 0.9201 - lr: 4.0960e-06
# Epoch 24/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1394 - accuracy: 0.9471
# Epoch 24: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 8s 103ms/step - loss: 0.1394 - accuracy: 0.9471 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 1.6384e-06
# Epoch 25/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1336 - accuracy: 0.9479
# Epoch 25: val_accuracy did not improve from 0.92014
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 6.553600542247295e-07.
# 81/81 [==============================] - 9s 110ms/step - loss: 0.1336 - accuracy: 0.9479 - val_loss: 0.2096 - val_accuracy: 0.9201 - lr: 1.6384e-06
# Epoch 26/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1382 - accuracy: 0.9448
# Epoch 26: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 8s 105ms/step - loss: 0.1382 - accuracy: 0.9448 - val_loss: 0.2097 - val_accuracy: 0.9201 - lr: 6.5536e-07
# Epoch 27/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1361 - accuracy: 0.9495
# Epoch 27: val_accuracy did not improve from 0.92014
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.6214402168989184e-07.
# 81/81 [==============================] - 9s 110ms/step - loss: 0.1361 - accuracy: 0.9495 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 6.5536e-07
# Epoch 28/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1379 - accuracy: 0.9441
# Epoch 28: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 9s 110ms/step - loss: 0.1379 - accuracy: 0.9441 - val_loss: 0.2096 - val_accuracy: 0.9201 - lr: 2.6214e-07
# Epoch 29/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9421
# Epoch 29: val_accuracy did not improve from 0.92014
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0485761094969349e-07.
# 81/81 [==============================] - 8s 103ms/step - loss: 0.1384 - accuracy: 0.9421 - val_loss: 0.2096 - val_accuracy: 0.9201 - lr: 2.6214e-07
# Epoch 30/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.9475
# Epoch 30: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 8s 103ms/step - loss: 0.1453 - accuracy: 0.9475 - val_loss: 0.2096 - val_accuracy: 0.9201 - lr: 1.0486e-07
# Epoch 31/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1342 - accuracy: 0.9468
# Epoch 31: val_accuracy did not improve from 0.92014
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.1943044948311586e-08.
# 81/81 [==============================] - 8s 105ms/step - loss: 0.1342 - accuracy: 0.9468 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 1.0486e-07
# Epoch 32/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9529
# Epoch 32: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 8s 103ms/step - loss: 0.1320 - accuracy: 0.9529 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 4.1943e-08
# Epoch 33/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1381 - accuracy: 0.9468
# Epoch 33: val_accuracy did not improve from 0.92014
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.677721854775882e-08.
# 81/81 [==============================] - 8s 104ms/step - loss: 0.1381 - accuracy: 0.9468 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 4.1943e-08
# Epoch 34/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1390 - accuracy: 0.9444
# Epoch 34: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 8s 104ms/step - loss: 0.1390 - accuracy: 0.9444 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 1.6777e-08
# Epoch 35/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1391 - accuracy: 0.9429
# Epoch 35: val_accuracy did not improve from 0.92014
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.710887134886434e-09.
# 81/81 [==============================] - 8s 104ms/step - loss: 0.1391 - accuracy: 0.9429 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 1.6777e-08
# Epoch 36/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9483
# Epoch 36: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 9s 110ms/step - loss: 0.1340 - accuracy: 0.9483 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 6.7109e-09
# Epoch 37/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1359 - accuracy: 0.9460
# Epoch 37: val_accuracy did not improve from 0.92014
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 2.6843547829003003e-09.
# 81/81 [==============================] - 9s 109ms/step - loss: 0.1359 - accuracy: 0.9460 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 6.7109e-09
# Epoch 38/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1412 - accuracy: 0.9437
# Epoch 38: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 9s 109ms/step - loss: 0.1412 - accuracy: 0.9437 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 2.6844e-09
# Epoch 39/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9483
# Epoch 39: val_accuracy did not improve from 0.92014
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.0737418953965518e-09.
# 81/81 [==============================] - 8s 104ms/step - loss: 0.1343 - accuracy: 0.9483 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 2.6844e-09
# Epoch 40/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9444
# Epoch 40: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 9s 109ms/step - loss: 0.1380 - accuracy: 0.9444 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 1.0737e-09
# Epoch 41/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9429
# Epoch 41: val_accuracy did not improve from 0.92014
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.294967492768365e-10.
# 81/81 [==============================] - 9s 110ms/step - loss: 0.1400 - accuracy: 0.9429 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 1.0737e-09
# Epoch 42/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9479
# Epoch 42: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 9s 111ms/step - loss: 0.1344 - accuracy: 0.9479 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 4.2950e-10
# Epoch 43/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1330 - accuracy: 0.9479
# Epoch 43: val_accuracy did not improve from 0.92014
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.7179869749028854e-10.
# 81/81 [==============================] - 8s 104ms/step - loss: 0.1330 - accuracy: 0.9479 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 4.2950e-10
# Epoch 44/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9506
# Epoch 44: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 8s 105ms/step - loss: 0.1302 - accuracy: 0.9506 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 1.7180e-10
# Epoch 45/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9433
# Epoch 45: val_accuracy did not improve from 0.92014
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 6.871948010633844e-11.
# 81/81 [==============================] - 9s 109ms/step - loss: 0.1408 - accuracy: 0.9433 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 1.7180e-10
# Epoch 46/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 0.9433
# Epoch 46: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 8s 103ms/step - loss: 0.1428 - accuracy: 0.9433 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 6.8719e-11
# Epoch 47/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1319 - accuracy: 0.9456
# Epoch 47: val_accuracy did not improve from 0.92014
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 2.748779259764689e-11.
# 81/81 [==============================] - 9s 109ms/step - loss: 0.1319 - accuracy: 0.9456 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 6.8719e-11
# Epoch 48/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9452
# Epoch 48: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 9s 109ms/step - loss: 0.1384 - accuracy: 0.9452 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 2.7488e-11
# Epoch 49/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 0.9514
# Epoch 49: val_accuracy did not improve from 0.92014
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.0995117316614512e-11.
# 81/81 [==============================] - 9s 110ms/step - loss: 0.1268 - accuracy: 0.9514 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 2.7488e-11
# Epoch 50/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9444
# Epoch 50: val_accuracy did not improve from 0.92014
# 81/81 [==============================] - 9s 110ms/step - loss: 0.1422 - accuracy: 0.9444 - val_loss: 0.2095 - val_accuracy: 0.9201 - lr: 1.0995e-11

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# Out:
# <ipython-input-19-036bcfb1f050>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy',fontweight='bold')
plt.xlim([0,50])
plt.ylim([min(plt.ylim()),1.005])
plt.title('Training and Validation Accuracy',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
# plt.legend(loc='best')
plt.savefig('DenseNet121TV1',dpi=400)
plt.show()

# %%
acc = history.history['loss']
val_acc = history.history['val_loss']

plt.plot(acc, label='Training loss')
plt.plot(val_acc, label='Validation loss')
plt.legend(loc='upper right')
plt.ylabel('Loss',fontweight='bold')
plt.xlim([-0.05,50])
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation loss',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
# plt.legend(loc='best')
plt.savefig('DenseNet121TV',dpi=400)
plt.show()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 10/10 [==============================] - 3s 94ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       196
#            1       0.92      0.90      0.91       124
#
#     accuracy                           0.93       320
#    macro avg       0.93      0.92      0.92       320
# weighted avg       0.93      0.93      0.93       320

# %%
cm = confusion_matrix(y_test_new, pred)

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
import itertools
from itertools import product
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues, fontweight='bold'):
    
    plt.figure(figsize=(7,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=40)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontweight='bold')
    plt.xlabel('Predicted label', fontweight='bold')

plot_confusion_matrix(cm,labels)
plt.savefig('DenseNet121CM',dpi=400)
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score

print('Accuracy: %.3f' % accuracy_score(y_test_new, pred), 'Precision: %.3f' % precision_score(y_test_new, pred),' Recall: %.3f' % recall_score(y_test_new, pred), 
      'F1 Score: %.3f' % f1_score(y_test_new, pred), 'AUC Score: %.3f' % roc_auc_score(y_test_new, pred))
# Out:
# Accuracy: 0.928 Precision: 0.917  Recall: 0.895 F1 Score: 0.906 AUC Score: 0.922

# %%
TP=cm[1,1]
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0]

# %%
specificity=TN/float(TN+FP)
print('Specificity: %.3f' % specificity)
# Out:
# Specificity: 0.949

# %%
recall=TP/float(TP+FN)
print(' Recall: %.5f' % recall)
precision=TP/float(TP+FP)
print(' Precision: %.5f' % precision)
# Out:
#  Recall: 0.89516
#  Precision: 0.91736

# %%
f1=(2*precision*recall)/(recall+precision)
print('F1 Score: %.5f' % f1)
# Out:
# F1 Score: 0.90612

# %%
print( 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# AUC Score: 0.92207

# %%
from sklearn.metrics import mean_squared_error
print( 'Error Rate: %.5f' % mean_squared_error(y_test_new, pred))
# Out:
# Error Rate: 0.07187

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
#Print Area Under Curve
false_positive_rate, recall, thresholds = roc_curve(y_test_new, pred)
roc_auc = auc(false_positive_rate, recall)
plt.figure()
plt.title('Receiver Operating Characteristic (ROC) Curve', fontweight='bold')
plt.plot(false_positive_rate, recall, 'b', label = 'DenseNet121 (AUC = %0.5f)' %roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1], 'r--')
plt.xlim([-0.01,1.0])
plt.ylim([0.0,1.01])
plt.ylabel('Recall', fontweight='bold')
plt.xlabel('Fall-out (1-Specificity)', fontweight='bold')
plt.savefig('DenseNet121AUC',dpi=400)
plt.show()
# Out:
# <ipython-input-33-fbdeb050ffe1>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
acc = accuracy_score(y_test_new, pred)*100
auc=roc_auc_score(y_test_new, pred)*100
tn, fp, fn, tp = cm.ravel()
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
specificity = tn/(tn+fp)*100
print('Accuracy: {0:0.2f}%'.format(acc))
print('Precision: {0:0.2f}%'.format(precision))
print('Recall or Sensitivity: {0:0.2f}%'.format(recall))
print('Specificity: {0:0.2f}%'.format(specificity))
print('F1-score: {0:0.2f}%'.format(2*precision*recall/(precision+recall)))
print('AUC-score: {0:0.2f}%'.format(auc))
print('Train acc: {0:0.2f}%'.format(np.round((history.history['accuracy'][-1])*100, 2)))
# Out:
# Accuracy: 92.81%
# Precision: 91.74%
# Recall or Sensitivity: 89.52%
# Specificity: 94.90%
# F1-score: 90.61%
# AUC-score: 92.21%
# Train acc: 94.44%
