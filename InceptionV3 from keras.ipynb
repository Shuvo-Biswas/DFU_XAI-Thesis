# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives, Precision, Recall, AUC
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
labels = ['Abnormal(Ulcer)','Normal(Healthy skin)']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/DFU_dataset','train',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        try:
            img = cv2.resize(img,(image_size, image_size))
        except:
            break
        X_train.append(img)
        y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/DFU_dataset','test',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 1740/1740 [00:42<00:00, 40.68it/s]
# 100%|██████████| 1170/1170 [00:16<00:00, 72.32it/s]
# 100%|██████████| 175/175 [00:03<00:00, 50.01it/s]
# 100%|██████████| 115/115 [00:01<00:00, 99.42it/s]

# %%
X_train.shape
# Out:
# (3200, 224, 224, 3)

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=1010)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=1010)

# %%
X_test.shape
# Out:
# (320, 224, 224, 3)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import keras
import keras.utils
from keras import utils as np_utils
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils.vis_utils import plot_model

from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential

# %%
IMAGE_SIZE = [224, 224]

# %%
inception = InceptionV3(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
for layer in inception.layers:
    layer.trainable = False
x = GlobalAveragePooling2D()(inception.output)
x = Dense(1024,activation='relu')(x)
x = Dropout(rate=0.5)(x)
x = Dense(1024,activation='relu')(x)
x = Dropout(rate=0.3)(x)
x = Dense(512,activation='relu')(x)
prediction = Dense(2, activation='softmax')(x)

# create a model object
model = Model(inputs=inception.input, outputs=prediction)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
model.summary()
# plot model architecture
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, to_file='inception.png')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= 'accuracy')

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("inception.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.4, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/50
# 81/81 [==============================] - ETA: 0s - loss: 3.7696 - accuracy: 0.7064
# Epoch 1: val_accuracy improved from -inf to 0.73611, saving model to inception.h5
# 81/81 [==============================] - 23s 103ms/step - loss: 3.7696 - accuracy: 0.7064 - val_loss: 0.5309 - val_accuracy: 0.7361 - lr: 0.0010
# Epoch 2/50
# 81/81 [==============================] - ETA: 0s - loss: 0.5346 - accuracy: 0.7716
# Epoch 2: val_accuracy did not improve from 0.73611
# 81/81 [==============================] - 6s 78ms/step - loss: 0.5346 - accuracy: 0.7716 - val_loss: 0.5610 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 3/50
# 81/81 [==============================] - ETA: 0s - loss: 0.4700 - accuracy: 0.7940
# Epoch 3: val_accuracy improved from 0.73611 to 0.83333, saving model to inception.h5
# 81/81 [==============================] - 7s 87ms/step - loss: 0.4700 - accuracy: 0.7940 - val_loss: 0.4342 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 4/50
# 81/81 [==============================] - ETA: 0s - loss: 0.4607 - accuracy: 0.7990
# Epoch 4: val_accuracy did not improve from 0.83333
# 81/81 [==============================] - 7s 83ms/step - loss: 0.4607 - accuracy: 0.7990 - val_loss: 0.4794 - val_accuracy: 0.8264 - lr: 0.0010
# Epoch 5/50
# 81/81 [==============================] - ETA: 0s - loss: 0.4436 - accuracy: 0.7990
# Epoch 5: val_accuracy improved from 0.83333 to 0.84028, saving model to inception.h5
# 81/81 [==============================] - 7s 88ms/step - loss: 0.4436 - accuracy: 0.7990 - val_loss: 0.4638 - val_accuracy: 0.8403 - lr: 0.0010
# Epoch 6/50
# 81/81 [==============================] - ETA: 0s - loss: 0.4433 - accuracy: 0.8079
# Epoch 6: val_accuracy improved from 0.84028 to 0.84722, saving model to inception.h5
# 81/81 [==============================] - 7s 86ms/step - loss: 0.4433 - accuracy: 0.8079 - val_loss: 0.4249 - val_accuracy: 0.8472 - lr: 0.0010
# Epoch 7/50
# 81/81 [==============================] - ETA: 0s - loss: 0.4278 - accuracy: 0.8221
# Epoch 7: val_accuracy improved from 0.84722 to 0.85069, saving model to inception.h5
# 81/81 [==============================] - 8s 94ms/step - loss: 0.4278 - accuracy: 0.8221 - val_loss: 0.4059 - val_accuracy: 0.8507 - lr: 0.0010
# Epoch 8/50
# 81/81 [==============================] - ETA: 0s - loss: 0.4175 - accuracy: 0.8229
# Epoch 8: val_accuracy did not improve from 0.85069
# 81/81 [==============================] - 6s 78ms/step - loss: 0.4175 - accuracy: 0.8229 - val_loss: 0.4073 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 9/50
# 81/81 [==============================] - ETA: 0s - loss: 0.4230 - accuracy: 0.8202
# Epoch 9: val_accuracy did not improve from 0.85069
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 81/81 [==============================] - 6s 77ms/step - loss: 0.4230 - accuracy: 0.8202 - val_loss: 0.4595 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 10/50
# 81/81 [==============================] - ETA: 0s - loss: 0.4027 - accuracy: 0.8272
# Epoch 10: val_accuracy did not improve from 0.85069
# 81/81 [==============================] - 7s 81ms/step - loss: 0.4027 - accuracy: 0.8272 - val_loss: 0.3738 - val_accuracy: 0.8368 - lr: 4.0000e-04
# Epoch 11/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3858 - accuracy: 0.8449
# Epoch 11: val_accuracy improved from 0.85069 to 0.86111, saving model to inception.h5
# 81/81 [==============================] - 8s 95ms/step - loss: 0.3858 - accuracy: 0.8449 - val_loss: 0.3698 - val_accuracy: 0.8611 - lr: 4.0000e-04
# Epoch 12/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3740 - accuracy: 0.8484
# Epoch 12: val_accuracy did not improve from 0.86111
# 81/81 [==============================] - 6s 77ms/step - loss: 0.3740 - accuracy: 0.8484 - val_loss: 0.3906 - val_accuracy: 0.8368 - lr: 4.0000e-04
# Epoch 13/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3714 - accuracy: 0.8484
# Epoch 13: val_accuracy improved from 0.86111 to 0.86806, saving model to inception.h5
# 81/81 [==============================] - 9s 106ms/step - loss: 0.3714 - accuracy: 0.8484 - val_loss: 0.3847 - val_accuracy: 0.8681 - lr: 4.0000e-04
# Epoch 14/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3738 - accuracy: 0.8441
# Epoch 14: val_accuracy did not improve from 0.86806
# 81/81 [==============================] - 6s 78ms/step - loss: 0.3738 - accuracy: 0.8441 - val_loss: 0.4078 - val_accuracy: 0.8507 - lr: 4.0000e-04
# Epoch 15/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3579 - accuracy: 0.8476
# Epoch 15: val_accuracy did not improve from 0.86806
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 81/81 [==============================] - 6s 79ms/step - loss: 0.3579 - accuracy: 0.8476 - val_loss: 0.3376 - val_accuracy: 0.8542 - lr: 4.0000e-04
# Epoch 16/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3442 - accuracy: 0.8576
# Epoch 16: val_accuracy improved from 0.86806 to 0.87153, saving model to inception.h5
# 81/81 [==============================] - 7s 91ms/step - loss: 0.3442 - accuracy: 0.8576 - val_loss: 0.3801 - val_accuracy: 0.8715 - lr: 1.6000e-04
# Epoch 17/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3435 - accuracy: 0.8603
# Epoch 17: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 78ms/step - loss: 0.3435 - accuracy: 0.8603 - val_loss: 0.3577 - val_accuracy: 0.8681 - lr: 1.6000e-04
# Epoch 18/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3380 - accuracy: 0.8569
# Epoch 18: val_accuracy did not improve from 0.87153
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 81/81 [==============================] - 7s 84ms/step - loss: 0.3380 - accuracy: 0.8569 - val_loss: 0.3450 - val_accuracy: 0.8542 - lr: 1.6000e-04
# Epoch 19/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3346 - accuracy: 0.8700
# Epoch 19: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 7s 92ms/step - loss: 0.3346 - accuracy: 0.8700 - val_loss: 0.3500 - val_accuracy: 0.8611 - lr: 6.4000e-05
# Epoch 20/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3293 - accuracy: 0.8650
# Epoch 20: val_accuracy did not improve from 0.87153
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 81/81 [==============================] - 6s 80ms/step - loss: 0.3293 - accuracy: 0.8650 - val_loss: 0.3531 - val_accuracy: 0.8611 - lr: 6.4000e-05
# Epoch 21/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.8661
# Epoch 21: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 80ms/step - loss: 0.3269 - accuracy: 0.8661 - val_loss: 0.3584 - val_accuracy: 0.8681 - lr: 2.5600e-05
# Epoch 22/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3217 - accuracy: 0.8627
# Epoch 22: val_accuracy did not improve from 0.87153
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 81/81 [==============================] - 6s 79ms/step - loss: 0.3217 - accuracy: 0.8627 - val_loss: 0.3511 - val_accuracy: 0.8611 - lr: 2.5600e-05
# Epoch 23/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3165 - accuracy: 0.8692
# Epoch 23: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 7s 83ms/step - loss: 0.3165 - accuracy: 0.8692 - val_loss: 0.3495 - val_accuracy: 0.8576 - lr: 1.0240e-05
# Epoch 24/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3170 - accuracy: 0.8727
# Epoch 24: val_accuracy did not improve from 0.87153
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# 81/81 [==============================] - 6s 79ms/step - loss: 0.3170 - accuracy: 0.8727 - val_loss: 0.3516 - val_accuracy: 0.8611 - lr: 1.0240e-05
# Epoch 25/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3174 - accuracy: 0.8681
# Epoch 25: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 79ms/step - loss: 0.3174 - accuracy: 0.8681 - val_loss: 0.3509 - val_accuracy: 0.8611 - lr: 4.0960e-06
# Epoch 26/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3111 - accuracy: 0.8684
# Epoch 26: val_accuracy did not improve from 0.87153
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.6384001355618238e-06.
# 81/81 [==============================] - 6s 77ms/step - loss: 0.3111 - accuracy: 0.8684 - val_loss: 0.3511 - val_accuracy: 0.8611 - lr: 4.0960e-06
# Epoch 27/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3152 - accuracy: 0.8715
# Epoch 27: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 79ms/step - loss: 0.3152 - accuracy: 0.8715 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 1.6384e-06
# Epoch 28/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3135 - accuracy: 0.8673
# Epoch 28: val_accuracy did not improve from 0.87153
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.553600542247295e-07.
# 81/81 [==============================] - 6s 79ms/step - loss: 0.3135 - accuracy: 0.8673 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 1.6384e-06
# Epoch 29/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3141 - accuracy: 0.8681
# Epoch 29: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 79ms/step - loss: 0.3141 - accuracy: 0.8681 - val_loss: 0.3507 - val_accuracy: 0.8611 - lr: 6.5536e-07
# Epoch 30/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3138 - accuracy: 0.8742
# Epoch 30: val_accuracy did not improve from 0.87153
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.6214402168989184e-07.
# 81/81 [==============================] - 6s 77ms/step - loss: 0.3138 - accuracy: 0.8742 - val_loss: 0.3507 - val_accuracy: 0.8611 - lr: 6.5536e-07
# Epoch 31/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3159 - accuracy: 0.8746
# Epoch 31: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 78ms/step - loss: 0.3159 - accuracy: 0.8746 - val_loss: 0.3507 - val_accuracy: 0.8611 - lr: 2.6214e-07
# Epoch 32/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3108 - accuracy: 0.8735
# Epoch 32: val_accuracy did not improve from 0.87153
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.0485761094969349e-07.
# 81/81 [==============================] - 6s 78ms/step - loss: 0.3108 - accuracy: 0.8735 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 2.6214e-07
# Epoch 33/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3139 - accuracy: 0.8746
# Epoch 33: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 78ms/step - loss: 0.3139 - accuracy: 0.8746 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 1.0486e-07
# Epoch 34/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3145 - accuracy: 0.8715
# Epoch 34: val_accuracy did not improve from 0.87153
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 4.1943044948311586e-08.
# 81/81 [==============================] - 6s 77ms/step - loss: 0.3145 - accuracy: 0.8715 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 1.0486e-07
# Epoch 35/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.8627
# Epoch 35: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 77ms/step - loss: 0.3178 - accuracy: 0.8627 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 4.1943e-08
# Epoch 36/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3187 - accuracy: 0.8715
# Epoch 36: val_accuracy did not improve from 0.87153
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.677721854775882e-08.
# 81/81 [==============================] - 7s 83ms/step - loss: 0.3187 - accuracy: 0.8715 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 4.1943e-08
# Epoch 37/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3154 - accuracy: 0.8742
# Epoch 37: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 77ms/step - loss: 0.3154 - accuracy: 0.8742 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 1.6777e-08
# Epoch 38/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3142 - accuracy: 0.8723
# Epoch 38: val_accuracy did not improve from 0.87153
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.710887134886434e-09.
# 81/81 [==============================] - 6s 78ms/step - loss: 0.3142 - accuracy: 0.8723 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 1.6777e-08
# Epoch 39/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3188 - accuracy: 0.8677
# Epoch 39: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 77ms/step - loss: 0.3188 - accuracy: 0.8677 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 6.7109e-09
# Epoch 40/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3106 - accuracy: 0.8677
# Epoch 40: val_accuracy did not improve from 0.87153
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 2.6843547829003003e-09.
# 81/81 [==============================] - 6s 78ms/step - loss: 0.3106 - accuracy: 0.8677 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 6.7109e-09
# Epoch 41/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3175 - accuracy: 0.8696
# Epoch 41: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 78ms/step - loss: 0.3175 - accuracy: 0.8696 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 2.6844e-09
# Epoch 42/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3121 - accuracy: 0.8715
# Epoch 42: val_accuracy did not improve from 0.87153
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.0737418953965518e-09.
# 81/81 [==============================] - 6s 79ms/step - loss: 0.3121 - accuracy: 0.8715 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 2.6844e-09
# Epoch 43/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3076 - accuracy: 0.8789
# Epoch 43: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 78ms/step - loss: 0.3076 - accuracy: 0.8789 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 1.0737e-09
# Epoch 44/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3191 - accuracy: 0.8684
# Epoch 44: val_accuracy did not improve from 0.87153
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 4.294967492768365e-10.
# 81/81 [==============================] - 6s 79ms/step - loss: 0.3191 - accuracy: 0.8684 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 1.0737e-09
# Epoch 45/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3177 - accuracy: 0.8673
# Epoch 45: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 78ms/step - loss: 0.3177 - accuracy: 0.8673 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 4.2950e-10
# Epoch 46/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3064 - accuracy: 0.8727
# Epoch 46: val_accuracy did not improve from 0.87153
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.7179869749028854e-10.
# 81/81 [==============================] - 6s 80ms/step - loss: 0.3064 - accuracy: 0.8727 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 4.2950e-10
# Epoch 47/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3039 - accuracy: 0.8723
# Epoch 47: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 78ms/step - loss: 0.3039 - accuracy: 0.8723 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 1.7180e-10
# Epoch 48/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3148 - accuracy: 0.8704
# Epoch 48: val_accuracy did not improve from 0.87153
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.871948010633844e-11.
# 81/81 [==============================] - 6s 79ms/step - loss: 0.3148 - accuracy: 0.8704 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 1.7180e-10
# Epoch 49/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3070 - accuracy: 0.8777
# Epoch 49: val_accuracy did not improve from 0.87153
# 81/81 [==============================] - 6s 78ms/step - loss: 0.3070 - accuracy: 0.8777 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 6.8719e-11
# Epoch 50/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3161 - accuracy: 0.8696
# Epoch 50: val_accuracy did not improve from 0.87153
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 2.748779259764689e-11.
# 81/81 [==============================] - 6s 79ms/step - loss: 0.3161 - accuracy: 0.8696 - val_loss: 0.3506 - val_accuracy: 0.8611 - lr: 6.8719e-11

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy',fontweight='bold')
plt.xlim([0,50])
plt.ylim([min(plt.ylim()),1.005])
plt.title('Training and Validation Accuracy',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
# plt.legend(loc='best')
plt.savefig('inceptionTV15',dpi=400)
plt.show()
# Out:
# <ipython-input-22-1625b617bc78>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# Out:
# <ipython-input-23-036bcfb1f050>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
acc = history.history['loss']
val_acc = history.history['val_loss']

plt.plot(acc, label='Training loss')
plt.plot(val_acc, label='Validation loss')
plt.legend(loc='upper right')
plt.ylabel('Loss',fontweight='bold')
plt.xlim([-0.05,50])
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation loss',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
# plt.legend(loc='best')
plt.savefig('inceptionTV31',dpi=400)
plt.show()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 10/10 [==============================] - 2s 71ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89       196
#            1       0.81      0.84      0.83       124
#
#     accuracy                           0.86       320
#    macro avg       0.85      0.86      0.86       320
# weighted avg       0.86      0.86      0.86       320

# %%
cm = confusion_matrix(y_test_new, pred)

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
import itertools
from itertools import product
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues, fontweight='bold'):
    
    plt.figure(figsize=(7,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=40)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontweight='bold')
    plt.xlabel('Predicted label', fontweight='bold')

plot_confusion_matrix(cm,labels)
plt.savefig('inceptionCM11',dpi=400)
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score

print('Accuracy: %.3f' % accuracy_score(y_test_new, pred), 'Precision: %.3f' % precision_score(y_test_new, pred),' Recall: %.3f' % recall_score(y_test_new, pred), 
      'F1 Score: %.3f' % f1_score(y_test_new, pred), 'AUC Score: %.3f' % roc_auc_score(y_test_new, pred))
# Out:
# Accuracy: 0.863 Precision: 0.812  Recall: 0.839 F1 Score: 0.825 AUC Score: 0.858

# %%
TP=cm[1,1]
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0]

# %%
specificity=TN/float(TN+FP)
print('Specificity: %.3f' % specificity)
# Out:
# Specificity: 0.878

# %%
recall=TP/float(TP+FN)
print(' Recall: %.5f' % recall)
precision=TP/float(TP+FP)
print(' Precision: %.5f' % precision)
# Out:
#  Recall: 0.83871
#  Precision: 0.81250

# %%
f1=(2*precision*recall)/(recall+precision)
print('F1 Score: %.5f' % f1)
# Out:
# F1 Score: 0.82540

# %%
print( 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# AUC Score: 0.85813

# %%
from sklearn.metrics import mean_squared_error
print( 'Error Rate: %.5f' % mean_squared_error(y_test_new, pred))
# Out:
# Error Rate: 0.13750

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
#Print Area Under Curve
false_positive_rate, recall, thresholds = roc_curve(y_test_new, pred)
roc_auc = auc(false_positive_rate, recall)
plt.figure()
plt.title('Receiver Operating Characteristic (ROC) Curve', fontweight='bold')
plt.plot(false_positive_rate, recall, 'b', label = 'InceptionV3 (AUC = %0.5f)' %roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1], 'r--')
plt.xlim([-0.01,1.0])
plt.ylim([0.0,1.01])
plt.ylabel('Recall', fontweight='bold')
plt.xlabel('Fall-out (1-Specificity)', fontweight='bold')
plt.savefig('inceptionAUC',dpi=400)
plt.show()
# Out:
# <ipython-input-36-f91379522d4c>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
acc = accuracy_score(y_test_new, pred)*100
auc=roc_auc_score(y_test_new, pred)*100
tn, fp, fn, tp = cm.ravel()
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
specificity = tn/(tn+fp)*100
print('Accuracy: {0:0.2f}%'.format(acc))
print('Precision: {0:0.2f}%'.format(precision))
print('Recall or Sensitivity: {0:0.2f}%'.format(recall))
print('Specificity: {0:0.2f}%'.format(specificity))
print('F1-score: {0:0.2f}%'.format(2*precision*recall/(precision+recall)))
print('AUC-score: {0:0.2f}%'.format(auc))
print('Train acc: {0:0.2f}%'.format(np.round((history.history['accuracy'][-1])*100, 2)))
# Out:
# Accuracy: 86.25%
# Precision: 81.25%
# Recall or Sensitivity: 83.87%
# Specificity: 87.76%
# F1-score: 82.54%
# AUC-score: 85.81%
# Train acc: 86.96%
